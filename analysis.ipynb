# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\Mbad9925\Desktop\A380 analysis\L0001V1255_POSTMOD_V1255_FT_POSTPROC.xlsx', sheet_name='Data')

# %%
df.drop(df.index[[0,2]])
df.head()
# Out:
#    Unnamed: 0            Unnamed: 1  \
# 0         NaN                   GMT
# 1         NaN                   NaN
# 2         1.0  131-09:43:08-000.000
# 3         2.0  131-09:43:08-062.500
# 4         3.0  131-09:43:08-125.000
#
#   PYLON - STRAIN - BLEED DUCT LOWER ROD - OUT OF LUG PLANE BENDING  \
# 0                                         50647001--
# 1                                                NaN
# 2                                          10.996094
# 3                                           4.672852
# 4                                          10.170898
#
#   PYLON - STRAIN - BLEED DUCT LOWER ROD - IN LUG PLANE BENDING  \
# 0                                         50647011--
# 1                                                NaN
# 2                                         -21.441406
# 3                                         -19.242188
# 4                                         -17.592773
#
#   PYLON - STRAIN - BLEED DUCT LOWER ROD - AXIAL  \
# ...

# %%
df2 = df[df.columns[9:26]]

# %%
corrM = df.corr()

# %%
corrM
# Out:
#                                              Unnamed: 0  \
# Unnamed: 0                                     1.000000
# PRESSURE ALTITUDE (ALTITUDE)                  -0.309045
# Nx                                             0.640819
# Ny                                             0.071566
# Nz                                            -0.054411
# A/C PITCH (ALPHA)                             -0.417986
# CALIBRATED AIRCRAFT SPEED                     -0.370313
# Lower strut load                              -0.247453
# lower strut load (zeroed)                     -0.247453
# Lower strut load due to pressure               0.135935
# Lower strut load due to non pressure          -0.505758
# mid strut load                                 0.596712
# mid strut load (zeroed)                        0.596712
# mid strut load due to pressure                 0.135935
# mid strut load due to non pressure             0.612822
# upper strut load                               0.504585
# ...

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27

# %%
mask = np.triu(np.ones_like(corrM, dtype=np.bool))
heatmap = sns.heatmap(corrM, mask=mask, vmin=-1, vmax=1, annot=False, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
